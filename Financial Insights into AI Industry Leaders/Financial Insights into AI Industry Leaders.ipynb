# %% [markdown]
# # 📊 Analyse AI's Financial Market Data like a Pro with Python
#
# Welcome to this comprehensive financial market analysis project, where we dive deep into **AI-driven companies** and their revenue growth trends over time.
# In this notebook, we leverage **Python's powerful data science stack** — Pandas, NumPy, Seaborn, Plotly, and Matplotlib — to uncover patterns, correlations, and insights in AI companies’ financial performance.
#
# ### 🔍 What you'll find here:
# - **Data Cleaning & Preprocessing**: Handling missing values, data type conversions, and ensuring data integrity.
# - **Exploratory Data Analysis (EDA)**: Summarizing financial metrics and identifying growth patterns.
# - **Revenue Growth Visualization**: Comparing year-by-year AI revenue changes across companies like OpenAI, Google, and Meta.
# - **Correlation Analysis**: Understanding relationships between key financial indicators.
#
# 💡 **Goal**: Equip analysts, researchers, and enthusiasts with a clear and interactive understanding of how AI companies are performing in the ever-evolving financial market.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# importing the dataset
df=pd.read_csv(r"C:\Users\ADITYA TIWARI\OneDrive\Documents\DATAS SETS\ai_financial_market_daily_realistic_synthetic.csv")

# %%
df
# Out:
#              Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0      2015-01-01  OpenAI                 5.92               0.63
# 1      2015-01-02  OpenAI                 5.41               1.81
# 2      2015-01-03  OpenAI                 4.50               0.61
# 3      2015-01-04  OpenAI                 5.45               0.95
# 4      2015-01-05  OpenAI                 3.40               1.48
# ...           ...     ...                  ...                ...
# 10954  2024-12-27    Meta               100.19             103.54
# 10955  2024-12-28    Meta                99.12             102.37
# 10956  2024-12-29    Meta                98.95             103.11
# 10957  2024-12-30    Meta               100.74             103.21
# 10958  2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%
# 0                   -36.82   NaN           -0.36
# 1                    80.59   NaN            0.41
# ...

# %%
#Showing the basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10959 entries, 0 to 10958
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 10959 non-null  object
#  1   Company              10959 non-null  object
#  2   R&D_Spending_USD_Mn  10959 non-null  float64
#  3   AI_Revenue_USD_Mn    10959 non-null  float64
#  4   AI_Revenue_Growth_%  10959 non-null  float64
#  5   Event                233 non-null    object
#  6   Stock_Impact_%       10959 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 599.4+ KB

# %%
# from the info we can see Date Dtype is object not DateTime so we convert it !!
df['Date'] =pd.to_datetime(df["Date"])
df
# Out:
#             Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0     2015-01-01  OpenAI                 5.92               0.63
# 1     2015-01-02  OpenAI                 5.41               1.81
# 2     2015-01-03  OpenAI                 4.50               0.61
# 3     2015-01-04  OpenAI                 5.45               0.95
# 4     2015-01-05  OpenAI                 3.40               1.48
# ...          ...     ...                  ...                ...
# 10954 2024-12-27    Meta               100.19             103.54
# 10955 2024-12-28    Meta                99.12             102.37
# 10956 2024-12-29    Meta                98.95             103.11
# 10957 2024-12-30    Meta               100.74             103.21
# 10958 2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%
# 0                   -36.82   NaN           -0.36
# 1                    80.59   NaN            0.41
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10959 entries, 0 to 10958
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 10959 non-null  datetime64[ns]
#  1   Company              10959 non-null  object
#  2   R&D_Spending_USD_Mn  10959 non-null  float64
#  3   AI_Revenue_USD_Mn    10959 non-null  float64
#  4   AI_Revenue_Growth_%  10959 non-null  float64
#  5   Event                233 non-null    object
#  6   Stock_Impact_%       10959 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 599.4+ KB

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%
# 0               -36.82   NaN           -0.36
# 1                80.59   NaN            0.41
# 2               -38.88   NaN            0.23
# 3                -5.34   NaN            0.93
# 4                48.45   NaN           -0.09

# %%
#Show company name 
df['Company'].unique()
# Out:
# array(['OpenAI', 'Google', 'Meta'], dtype=object)

# %%
# Create a New Column for year only
df['Year'] = df['Date'].dt.year

# %%
df.head()
#Checking for any missing and null value
df.isnull().sum()
# Out:
# Date                       0
# Company                    0
# R&D_Spending_USD_Mn        0
# AI_Revenue_USD_Mn          0
# AI_Revenue_Growth_%        0
# Event                  10726
# Stock_Impact_%             0
# Year                       0
# dtype: int64

# %%
# Event when Gpt 4 was released
df[df['Event'] == 'GPT-4 release']
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 2994 2023-03-14  OpenAI                 7.78               4.05
#
#       AI_Revenue_Growth_%          Event  Stock_Impact_%  Year
# 2994               304.57  GPT-4 release            15.2  2023

# %% [markdown]
# # How much amount the Companies Spend on R & D

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
print("Company Spending on R&D in $Bn")
RD =df.groupby('Company')['R&D_Spending_USD_Mn'].sum()/1000
RD
# Out:
# Company Spending on R&D in $Bn
# Company
# Google    423.34114
# Meta      264.53307
# OpenAI     26.48277
# Name: R&D_Spending_USD_Mn, dtype: float64

# %%
sns.barplot(x=RD.index , y=RD.values , color='Red', edgecolor='black')
#sns.set_theme(style='w')
plt.title("Company R&D Spending" )
plt.xlabel("Company ")
plt.ylabel("Amount in USD_$Bn")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Revenue Earned by the Companies

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
RE =df.groupby('Company')['AI_Revenue_USD_Mn'].sum()/1000
RE
# Out:
# Company
# Google    284.49838
# Meta      189.62182
# OpenAI      9.46289
# Name: AI_Revenue_USD_Mn, dtype: float64

# %%
df2 = pd.DataFrame({
    'Company': RE.index,
    'Revenue': RE.values
})
fig = px.bar(
    df2,
    x='Company',
    y='Revenue',
    color='Revenue',
    color_continuous_scale='Viridis',
    hover_data={'Revenue': ':.2f'}  # format revenue with 2 decimals
)
fig.update_layout(
    title='Revenue Earned by Companies in USD_$Bn',
    xaxis_title='Company',
    yaxis_title='Revenue in USD_$Bn'
)
fig.show()

# %%
# bar plot to show company Revenue and Expenditure by each Company
sns.set_theme(style='darkgrid')
plt.figure(figsize=(11, 5))
plt.subplot(1 , 2 , 1)
plt.bar(RD.index , RE.values , color = ['#a6cee3', '#fdbf6f', '#b2df8a'] )
plt.xlabel("Company ")
plt.ylabel("Amount in USD_$Bn")

plt.subplot(1,2,2)
plt.bar(RE.index , RE.values ,color = ['#a6cee3', '#fdbf6f', '#b2df8a'] )
plt.xlabel('Company')
plt.ylabel('Revenue in USD_$Bn')
plt.title("Revenue Earned by Companies in USD_$Bn")

plt.tight_layout()
plt.show()

# %% [markdown]
# # DataWise impact on Stocks

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
sns.lineplot(data=df, x='Year', y='Stock_Impact_%', hue='Company',  markers=True, dashes=False)
plt.title('Stock impact on Company')
plt.xlabel("Company")
plt.ylabel("Stock_Impact_%")
plt.show()

# %% [markdown]
# ## Create 3 Seperate dataframe for each Company

# %%
data_openAi=df[df['Company'] == 'OpenAI']

# %%
data_Google=df[df['Company'] == 'Google']

# %%
data_Meta=df[df['Company'] == 'Meta']

# %% [markdown]
# ### Change in stock values of diffrent company

# %%
# stock impact on OpenAi
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(data_openAi['Year'], data_openAi['Stock_Impact_%'], color='#fdbf6f', marker='o')
plt.title("Change in Stock Value of OpenAI")
plt.xlabel("Year")
plt.ylabel("Stock Impact (%)")
plt.grid(True)
plt.show()

# %%
#Stock impact on Google

plt.figure(figsize=(10,5))
plt.plot(data_Google['Year'], data_Google['Stock_Impact_%'], color="#4b096f", marker='o')
plt.title("Change in Stock Value of Google")
plt.xlabel("Year")
plt.ylabel("Stock Impact (%)")
plt.grid(True)
plt.show()

# %%
#Stock impact on Meta

plt.figure(figsize=(10,5))
plt.plot(data_Meta['Year'], data_Meta['Stock_Impact_%'], color="#E70E65", marker='o')
plt.title("Change in Stock Value of Meta")
plt.xlabel("Year")
plt.ylabel("Stock Impact (%)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Events When Maximum Stock Impact was Observed

# %%
# Open-Ai's when Maximum Stock impact was observed
data_openAi.sort_values(by ='Stock_Impact_%' , ascending=False )
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3408 2024-05-01  OpenAI                10.91               5.34
# 2994 2023-03-14  OpenAI                 7.78               4.05
# 2890 2022-11-30  OpenAI                10.60               3.18
# 2652 2022-04-06  OpenAI                 9.24               3.48
# 1988 2020-06-11  OpenAI                 5.90               2.62
# ...         ...     ...                  ...                ...
# 3590 2024-10-30  OpenAI                11.05               5.27
# 1212 2018-04-27  OpenAI                 5.38               1.76
# 1303 2018-07-27  OpenAI                 7.44               0.97
# 2480 2021-10-16  OpenAI                 8.39               2.78
# 3350 2024-03-04  OpenAI                10.82               4.77
#
#       AI_Revenue_Growth_%                        Event  Stock_Impact_%  Year
# 3408               434.27    GPT-5 release (predicted)           18.50  2024
# ...

# %%
# Meta's when Maximum Stock impact was observed
data_Meta.sort_values(by='Stock_Impact_%' , ascending=False)
# Out:
#             Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 10731 2024-05-18    Meta               103.64             103.05
# 10426 2023-07-18    Meta                92.44              85.67
# 10282 2023-02-24    Meta                93.71              86.98
# 9156  2020-01-25    Meta                72.73              49.10
# 7526  2015-08-09    Meta                48.97              19.95
# ...          ...     ...                  ...                ...
# 10604 2024-01-12    Meta                99.37             104.28
# 7875  2016-07-23    Meta                53.76              23.97
# 8026  2016-12-21    Meta                53.18              23.42
# 9964  2022-04-12    Meta                84.90              71.99
# 10785 2024-07-11    Meta               100.78             102.92
#
#        AI_Revenue_Growth_%                            Event  Stock_Impact_%  \
# 10731               415.23      LLaMA 3 release (predicted)            7.40
# ...

# %%
# Google's when Maximum Stock impact was observed
data_Google.sort_values( by ='Stock_Impact_%' , ascending=False)
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 4092 2016-03-15  Google                84.56              36.22
# 6914 2023-12-06  Google               146.59             129.17
# 6654 2023-03-21  Google               149.34             129.76
# 3883 2015-08-19  Google                79.27              30.89
# 6388 2022-06-28  Google               137.71             107.96
# ...         ...     ...                  ...                ...
# 4122 2016-04-14  Google                87.19              36.08
# 4412 2017-01-29  Google                92.21              43.25
# 6303 2022-04-04  Google               138.00             106.81
# 3803 2015-05-31  Google                81.14              29.30
# 5479 2020-01-01  Google               117.24              74.82
#
#       AI_Revenue_Growth_%                            Event  Stock_Impact_%  \
# 4092                20.73          AlphaGo beats Lee Sedol            6.20
# ...

# %% [markdown]
# # AI Revenue Growth of the Company

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
sns.set_style('whitegrid')
plt.Figure(figsize=(10,20))
sns.scatterplot(x='Date' , y='AI_Revenue_Growth_%' , hue='Company' ,data=df)
plt.title("AI Revenue Growth of Companies")
plt.xlabel('Year')
plt.ylabel('I_Revenue_Growth_%')
plt.show()

# %% [markdown]
# # AI Revenue Growth Year-by-Year

# %%
data_openAi.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
data_openAi = data_openAi.copy()
data_Google = data_Google.copy()
data_Meta = data_Meta.copy()

data_openAi['Company'] = 'OpenAI'
data_Google['Company'] = 'Google'
data_Meta['Company'] = 'Meta'

# Combine all data
combined_df = pd.concat([data_openAi, data_Google, data_Meta])

# Plot grouped bar chart
plt.figure(figsize=(10, 6))
sns.barplot(
    x='Year',
    y='AI_Revenue_Growth_%',
    hue='Company',
    data=combined_df,
    palette='Set2'
)

plt.title("AI Revenue Growth Year-by-Year (OpenAI, Google, Meta)")
plt.xlabel('Year')
plt.ylabel('AI Revenue Growth (%)')
plt.legend(title='Company')
plt.show()

# %% [markdown]
# ## Corelation Between the Columns

# %%
corelation=df.corr(numeric_only=True)

sns.heatmap(corelation , cmap ='coolwarm' , annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Expenditure vs Revenue Year-by-Year

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
spend=df.groupby('Year')['R&D_Spending_USD_Mn'].sum()
revenue=df.groupby('Year')['AI_Revenue_USD_Mn'].sum()

# %%
plt.plot(spend.index , spend.values , color='r')
plt.plot(revenue.index , revenue.values , color='r')
plt.title("Combined Expenditure vs Revenue Year-by-Year")
plt.xlabel('Year')
plt.ylabel("Amount in USD_$Mn")
plt.show()

# %%
#pairplot of the given data df

sns.pairplot(df)
plt.show()

# %% [markdown]
# # Event Impact Analysis

# %%
df.Event.value_counts()
# Out:
# Event
# AI speech recognition release      37
# AI Ads Optimization upgrade        32
# AI partnership deal                32
# AI-powered search update           32
# AI Video Recommendation upgrade    29
# AI ethics policy update            27
# Cloud AI launch                    27
# GPT-1 release                       1
# GPT-2 release                       1
# GPT-3 release                       1
# Codex release                       1
# DALL·E 2 release                    1
# ChatGPT (GPT-3.5) launch            1
# GPT-4 release                       1
# GPT-5 release (predicted)           1
# TensorFlow open-source release      1
# AlphaGo beats Lee Sedol             1
# BERT for Search launch              1
# MUM Search Model launch             1
# Bard chatbot launch                 1
# Gemini AI release                   1
# LLaMA 1 release                     1
# LLaMA 2 release                     1
# LLaMA 3 release (predicted)         1
# Name: count, dtype: int64

# %%
# checking for paricular event 
df[df.Event =='TensorFlow open-source release']
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3965 2015-11-09  Google                79.62              29.84
#
#       AI_Revenue_Growth_%                           Event  Stock_Impact_%  \
# 3965                -0.53  TensorFlow open-source release             4.5
#
#       Year
# 3965  2015

# %%
tf=df.loc[3955 : 3975]
tf
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3955 2015-10-30  Google                80.33              29.87
# 3956 2015-10-31  Google                79.53              30.30
# 3957 2015-11-01  Google                80.37              29.86
# 3958 2015-11-02  Google                77.89              29.97
# 3959 2015-11-03  Google                81.00              29.43
# 3960 2015-11-04  Google                80.70              29.71
# 3961 2015-11-05  Google                78.31              30.25
# 3962 2015-11-06  Google                79.08              29.84
# 3963 2015-11-07  Google                79.65              30.34
# 3964 2015-11-08  Google                79.63              29.74
# 3965 2015-11-09  Google                79.62              29.84
# 3966 2015-11-10  Google                81.65              29.44
# 3967 2015-11-11  Google                78.67              30.02
# 3968 2015-11-12  Google                81.43              29.56
# ...

# %%
# showing the impact of TensorFlow open-source release	with the line chart
plt.figure(figsize=(10,4))
plt.plot(tf['Date'] ,tf['Stock_Impact_%'] , color='blue' )
plt.title("Comparision before and after the release of TensorFlow open-source release")
plt.xlabel('Date')
plt.ylabel('Change in Stock %')
plt.show()

# %%
#checking for a particular event 
df[df.Event =='GPT-4 release']
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 2994 2023-03-14  OpenAI                 7.78               4.05
#
#       AI_Revenue_Growth_%          Event  Stock_Impact_%  Year
# 2994               304.57  GPT-4 release            15.2  2023

# %%
gpt4 =df.loc[2984 : 3014]
gpt4
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 2984 2023-03-04  OpenAI                10.59               4.26
# 2985 2023-03-05  OpenAI                 8.24               3.58
# 2986 2023-03-06  OpenAI                 9.32               4.21
# 2987 2023-03-07  OpenAI                 8.52               4.13
# 2988 2023-03-08  OpenAI                 8.90               3.63
# 2989 2023-03-09  OpenAI                 8.44               4.64
# 2990 2023-03-10  OpenAI                 9.55               4.83
# 2991 2023-03-11  OpenAI                 8.34               3.95
# 2992 2023-03-12  OpenAI                 8.71               3.57
# 2993 2023-03-13  OpenAI                10.61               5.19
# 2994 2023-03-14  OpenAI                 7.78               4.05
# 2995 2023-03-15  OpenAI                12.31               4.44
# 2996 2023-03-16  OpenAI                10.60               4.64
# 2997 2023-03-17  OpenAI                10.77               4.78
# ...

# %%
plt.figure(figsize=(10,4))
plt.plot(gpt4['Date'] ,gpt4['Stock_Impact_%'] , color='blue' )
plt.title("Comparision before and after the release of Gpt-4 release")
plt.xlabel('Date')
plt.ylabel('Change in Stock %')
plt.show()

# %%
df.head(2)
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015

# %%
# daily average impact on the stock

df.groupby('Company')['Stock_Impact_%'].mean()*100
# Out:
# Company
# Google    2.620860
# Meta      0.976184
# OpenAI    4.070901
# Name: Stock_Impact_%, dtype: float64

# %%
# Daily Expenditure on R & D by the Companies

df.groupby('Company')['R&D_Spending_USD_Mn'].mean()
# Out:
# Company
# Google    115.888623
# Meta       72.415294
# OpenAI      7.249595
# Name: R&D_Spending_USD_Mn, dtype: float64

# %%
# Maximum impact on the company stocks
df.groupby('Company')['Stock_Impact_%'].max()
# Out:
# Company
# Google     6.2
# Meta       7.4
# OpenAI    18.5
# Name: Stock_Impact_%, dtype: float64

# %% [markdown]
# # Change in the index wrt to Year & Company

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
# highest change in the index 
stocks = df.groupby(['Year' , 'Company'])['Stock_Impact_%'].max()
stocks
# Out:
# Year  Company
# 2015  Google      4.96
#       Meta        4.80
#       OpenAI      3.92
# 2016  Google      6.20
#       Meta        2.14
#       OpenAI      4.66
# 2017  Google      4.42
#       Meta        4.21
#       OpenAI      4.63
# 2018  Google      1.97
#       Meta        4.54
#       OpenAI      4.94
# 2019  Google      3.20
#       Meta        1.86
#       OpenAI      4.20
# 2020  Google      4.18
#       Meta        4.86
#       OpenAI      8.50
# 2021  Google      4.10
#       Meta        4.80
#       OpenAI      7.20
# 2022  Google      4.88
#       Meta        3.98
#       OpenAI     12.00
# 2023  Google      5.80
#       Meta        6.80
#       OpenAI     15.20
# 2024  Google      2.89
#       Meta        7.40
#       OpenAI     18.50
# Name: Stock_Impact_%, dtype: float64

# %%
stocks.plot(kind ='barh' , color= ["#70f502", "#714204", "#1b0571"])
plt.title("Change in Index ")
plt.show()
